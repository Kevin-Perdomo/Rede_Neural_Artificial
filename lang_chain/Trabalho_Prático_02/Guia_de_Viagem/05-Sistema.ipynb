# %% [markdown]
# # 🚀 **05 - Sistema: Interface Unificada**
#
# ## 🎯 **Objetivo:**
# Sistema completo que integra todos os componentes: Pinecone + RAG + Chains + Router em uma interface única e intuitiva.
#
# ## 📋 **O que faremos:**
# 1. 🔗 **Integração Total**: Todos os notebooks anteriores unidos
# 2. 💬 **Interface de Chat**: Conversação natural com usuário
# 3. 📊 **Métricas em Tempo Real**: Performance e estatísticas
# 4. 🎨 **Demo Interativa**: Demonstração completa do sistema
#
# ---

# %% [markdown]
# ## 1️⃣ **Setup Completo**

# %%
# Imports completos
from pinecone import Pinecone
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate
# ✅ Removido: from langchain.chains import LLMChain (depreciado)
import os
import time
import json
from datetime import datetime
from typing import Dict, List, Any
from dotenv import load_dotenv

# Carregar variáveis de ambiente
load_dotenv()

print("📦 **SETUP SISTEMA COMPLETO**")
print("✅ Bibliotecas importadas")
print("✅ Variáveis de ambiente carregadas")

# Verificar credenciais
required_keys = ['PINECONE_API_KEY', 'GROQ_API_KEY']
missing_keys = [key for key in required_keys if not os.getenv(key)]

if missing_keys:
    print(f"⚠️ Configure as chaves: {', '.join(missing_keys)}")
else:
    print("✅ Todas as credenciais encontradas")

print("\n🚀 **INICIALIZANDO COMPONENTES...**")
# Out:
# 📦 **SETUP SISTEMA COMPLETO**
# ✅ Bibliotecas importadas
# ✅ Variáveis de ambiente carregadas
# ✅ Todas as credenciais encontradas
#
# 🚀 **INICIALIZANDO COMPONENTES...**

# %% [markdown]
# ## 2️⃣ **Componente 1: Pinecone (Base Vetorial)**

# %%
# Configurar Pinecone
PINECONE_API_KEY = os.getenv('PINECONE_API_KEY')
INDEX_NAME = "turismo-inteligente"

try:
    pc = Pinecone(api_key=PINECONE_API_KEY)
    index = pc.Index(INDEX_NAME)
    
    # Verificar conexão
    stats = index.describe_index_stats()
    print(f"📌 **PINECONE CONECTADO:**")
    print(f"   🗄️ Índice: {INDEX_NAME}")
    print(f"   📊 Vetores: {stats['total_vector_count']}")
    
except Exception as e:
    print(f"❌ Erro Pinecone: {e}")
    index = None
# Out:
# 📌 **PINECONE CONECTADO:**
#    🗄️ Índice: turismo-inteligente
#    📊 Vetores: 21

# %% [markdown]
# ## 3️⃣ **Componente 2: Modelos (LLM + Embeddings)**

# %%
# Inicializar modelos
GROQ_API_KEY = os.getenv('GROQ_API_KEY')

try:
    # LLM para geração
    llm_geracao = ChatGroq(
        groq_api_key=GROQ_API_KEY,
        model_name="llama-3.1-8b-instant",
        temperature=0.1
    )
    
    # LLM para classificação (temperatura zero)
    llm_router = ChatGroq(
        groq_api_key=GROQ_API_KEY,
        model_name="llama-3.1-8b-instant",
        temperature=0.0
    )
    
    # Embeddings
    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2",
        model_kwargs={'device': 'cpu'}
    )
    
    print(f"🧠 **MODELOS CARREGADOS:**")
    print(f"   ⚡ LLM Geração: llama-3.1-8b-instant (temp=0.1)")
    print(f"   🎯 LLM Router: llama-3.1-8b-instant (temp=0.0)")
    print(f"   🔢 Embeddings: all-MiniLM-L6-v2 (384d)")
    
except Exception as e:
    print(f"❌ Erro nos modelos: {e}")
    llm_geracao = llm_router = embeddings = None
# Out:
# 🧠 **MODELOS CARREGADOS:**
#    ⚡ LLM Geração: llama-3.1-8b-instant (temp=0.1)
#    🎯 LLM Router: llama-3.1-8b-instant (temp=0.0)
#    🔢 Embeddings: all-MiniLM-L6-v2 (384d)

# %% [markdown]
# ## 4️⃣ **Componente 3: Sistema RAG**

# %%
def buscar_contexto(query: str, top_k: int = 3, filtros: Dict = None) -> List[Dict]:
    """
    Busca contexto relevante no Pinecone.
    """
    if not index or not embeddings:
        return []
    
    try:
        # Gerar embedding
        query_embedding = embeddings.embed_query(query)
        
        # Buscar no Pinecone
        results = index.query(
            vector=query_embedding,
            top_k=top_k,
            include_metadata=True,
            filter=filtros
        )
        
        # Processar resultados
        documentos = []
        for match in results['matches']:
            doc = {
                'texto': match['metadata']['text'],
                'cidade': match['metadata']['cidade'],
                'tipo': match['metadata']['tipo'],
                'score': match['score']
            }
            documentos.append(doc)
        
        return documentos
        
    except Exception as e:
        print(f"⚠️ Erro na busca RAG: {e}")
        return []

print("🔍 **SISTEMA RAG CONFIGURADO**")
print("   ✅ Função de busca por similaridade")
print("   ✅ Processamento de contexto")
print("   ✅ Integração Pinecone + Embeddings")
# Out:
# 🔍 **SISTEMA RAG CONFIGURADO**
#    ✅ Função de busca por similaridade
#    ✅ Processamento de contexto
#    ✅ Integração Pinecone + Embeddings

# %% [markdown]
# ## 5️⃣ **Componente 4: Chains Especializadas**

# %%
# Templates das chains especializadas
templates = {
    'roteiro': """
🗺️ ESPECIALISTA EM ROTEIROS TURÍSTICOS

Contexto relevante:
{contexto}

Pergunta: {query}

Como especialista em roteiros, forneça informações detalhadas sobre pontos turísticos, 
atrações e roteiros otimizados. Seja específico e prático.

Resposta:""",

    'logistica': """
🚗 ESPECIALISTA EM LOGÍSTICA DE VIAGEM

Contexto relevante:
{contexto}

Pergunta: {query}

Como especialista em logística, forneça informações práticas sobre transporte, 
hospedagem e locomoção. Inclua detalhes operacionais úteis.

Resposta:""",

    'info-local': """
📍 ESPECIALISTA EM INFORMAÇÕES LOCAIS

Contexto relevante:
{contexto}

Pergunta: {query}

Como conhecedor local, compartilhe insights sobre cultura, costumes, gastronomia 
e dicas que só um local saberia. Seja caloroso e informativo.

Resposta:""",

    'traducao': """
🌐 ESPECIALISTA EM TRADUÇÃO E COMUNICAÇÃO

Contexto relevante:
{contexto}

Pergunta: {query}

Como especialista em tradução, forneça traduções precisas, frases úteis 
e dicas de comunicação. Inclua pronúncia quando possível.

Resposta:"""
}

# ✅ SINTAXE MODERNA: Criar chains com RunnableSequence
chains = {}
for nome, template in templates.items():
    prompt = PromptTemplate(
        input_variables=["contexto", "query"],
        template=template
    )
    chain = prompt | llm_geracao  # Sintaxe moderna
    chains[nome] = chain

print(f"⛓️ **CHAINS ESPECIALIZADAS CRIADAS (SINTAXE MODERNA):**")
for nome in chains.keys():
    print(f"   ✅ Chain {nome}")
# Out:
# ⛓️ **CHAINS ESPECIALIZADAS CRIADAS (SINTAXE MODERNA):**
#    ✅ Chain roteiro
#    ✅ Chain logistica
#    ✅ Chain info-local
#    ✅ Chain traducao

# %% [markdown]
# ## 6️⃣ **Componente 5: Sistema de Router**

# %%
# Template do router
template_router = """
Você é um classificador de intenções para consultas turísticas.

ESPECIALIDADES:
- roteiro: pontos turísticos, atrações, onde ir, o que visitar
- logistica: transporte, hospedagem, como chegar, aeroporto, hotel
- info-local: cultura, costumes, comida, segurança, dicas locais
- traducao: traduzir, idiomas, como dizer, frases úteis

CONSULTA: "{query}"

Responda APENAS com o nome da especialidade (roteiro, logistica, info-local, ou traducao):
"""

# ✅ SINTAXE MODERNA: Criar chain do router com RunnableSequence
prompt_router = PromptTemplate(
    input_variables=["query"],
    template=template_router
)

chain_router = prompt_router | llm_router  # Sintaxe moderna

def classificar_query(query: str) -> str:
    """
    Classifica a query e retorna a especialidade.
    """
    try:
        # ✅ SINTAXE MODERNA: Usar invoke() ao invés de run()
        resultado = chain_router.invoke({"query": query})
        
        # Extrair conteúdo da resposta
        if hasattr(resultado, 'content'):
            especialidade = resultado.content.strip().lower()
        else:
            especialidade = str(resultado).strip().lower()
        
        # Validar resultado
        if especialidade in chains:
            return especialidade
        
        # Fallback simples
        query_lower = query.lower()
        if any(word in query_lower for word in ['hotel', 'aeroporto', 'transporte']):
            return 'logistica'
        elif any(word in query_lower for word in ['traduz', 'dizer', 'falar']):
            return 'traducao'
        elif any(word in query_lower for word in ['cultura', 'comida', 'costume']):
            return 'info-local'
        else:
            return 'roteiro'
            
    except Exception as e:
        print(f"⚠️ Erro no router: {e}")
        return 'roteiro'

print("🎯 **SISTEMA DE ROUTER CONFIGURADO (SINTAXE MODERNA)**")
print("   ✅ Chain de classificação")
print("   ✅ Fallback automático")
print("   ✅ Validação de resultados")
# Out:
# 🎯 **SISTEMA DE ROUTER CONFIGURADO (SINTAXE MODERNA)**
#    ✅ Chain de classificação
#    ✅ Fallback automático
#    ✅ Validação de resultados

# %% [markdown]
# ## 7️⃣ **Sistema Completo Integrado**

# %%
class GuiaTurismoInteligente:
    """
    Sistema completo de guia turístico inteligente.
    """
    
    def __init__(self):
        self.stats = {
            'consultas_total': 0,
            'por_especialidade': {'roteiro': 0, 'logistica': 0, 'info-local': 0, 'traducao': 0},
            'tempo_medio': 0,
            'historico': []
        }
    
    def processar_consulta(self, query: str, mostrar_debug: bool = False) -> Dict[str, Any]:
        """
        Processa uma consulta completa do usuário.
        
        Returns:
            Dicionário com resposta e metadados
        """
        start_time = time.time()
        
        try:
            # 1. Classificar consulta
            especialidade = classificar_query(query)
            
            if mostrar_debug:
                print(f"🎯 Roteamento: {especialidade}")
            
            # 2. Buscar contexto relevante
            documentos = buscar_contexto(query, top_k=3)
            contexto = "\n".join([
                f"• {doc['cidade'].upper()}: {doc['texto']}"
                for doc in documentos
            ]) if documentos else "Contexto não encontrado."
            
            if mostrar_debug:
                print(f"🔍 Contexto: {len(documentos)} documentos")
            
            # 3. Executar chain especializada
            if especialidade in chains:
                # ✅ SINTAXE MODERNA: Usar invoke() ao invés de run()
                resultado = chains[especialidade].invoke({
                    "contexto": contexto,
                    "query": query
                })
                
                # Extrair conteúdo da resposta
                if hasattr(resultado, 'content'):
                    resposta = resultado.content
                else:
                    resposta = str(resultado)
            else:
                resposta = "❌ Especialidade não encontrada."
            
            # 4. Calcular métricas
            tempo_processamento = time.time() - start_time
            
            # 5. Atualizar estatísticas
            self.stats['consultas_total'] += 1
            self.stats['por_especialidade'][especialidade] += 1
            self.stats['tempo_medio'] = (
                (self.stats['tempo_medio'] * (self.stats['consultas_total'] - 1) + tempo_processamento) / 
                self.stats['consultas_total']
            )
            
            # 6. Salvar no histórico
            entry = {
                'timestamp': datetime.now().isoformat(),
                'query': query,
                'especialidade': especialidade,
                'tempo_ms': tempo_processamento * 1000,
                'contextos_encontrados': len(documentos)
            }
            self.stats['historico'].append(entry)
            
            return {
                'resposta': resposta,
                'especialidade': especialidade,
                'contextos': len(documentos),
                'tempo_ms': tempo_processamento * 1000,
                'sucesso': True
            }
            
        except Exception as e:
            return {
                'resposta': f"❌ Erro no processamento: {e}",
                'especialidade': None,
                'contextos': 0,
                'tempo_ms': (time.time() - start_time) * 1000,
                'sucesso': False
            }
    
    def consultar(self, pergunta: str) -> str:
        """
        Interface simples para consulta.
        """
        resultado = self.processar_consulta(pergunta)
        return resultado['resposta']
    
    def mostrar_estatisticas(self):
        """
        Exibe estatísticas do sistema.
        """
        print("📊 **ESTATÍSTICAS DO SISTEMA:**")
        print(f"   📈 Total de consultas: {self.stats['consultas_total']}")
        print(f"   ⚡ Tempo médio: {self.stats['tempo_medio']*1000:.1f}ms")
        print("\n   🎯 **Por especialidade:**")
        for esp, count in self.stats['por_especialidade'].items():
            print(f"     • {esp}: {count}")

# Inicializar sistema
guia = GuiaTurismoInteligente()

print("🚀 **SISTEMA COMPLETO INICIALIZADO (SINTAXE MODERNA)!**")
print("   ✅ Pinecone + RAG + Chains + Router")
print("   ✅ Interface unificada")
print("   ✅ Métricas em tempo real")
print("   ✅ Pronto para uso!")
# Out:
# 🚀 **SISTEMA COMPLETO INICIALIZADO (SINTAXE MODERNA)!**
#    ✅ Pinecone + RAG + Chains + Router
#    ✅ Interface unificada
#    ✅ Métricas em tempo real
#    ✅ Pronto para uso!

# %% [markdown]
# ## 8️⃣ **Demo Interativa**

# %%
# Demonstração completa do sistema
print("🎬 **DEMONSTRAÇÃO DO SISTEMA COMPLETO**\n")

consultas_demo = [
    "Quais são os principais pontos turísticos do Rio de Janeiro?",
    "Como ir do aeroporto Charles de Gaulle para o centro de Paris?",
    "Que pratos típicos franceses devo experimentar?",
    "Como dizer 'onde fica o banheiro' em francês?"
]

for i, pergunta in enumerate(consultas_demo, 1):
    print(f"💬 **CONSULTA {i}:**")
    print(f"👤 Usuario: {pergunta}\n")
    
    # Processar com debug
    resultado = guia.processar_consulta(pergunta, mostrar_debug=True)
    
    print(f"🤖 **Resposta ({resultado['especialidade']}) - {resultado['tempo_ms']:.0f}ms:**")
    print(resultado['resposta'])
    print("\n" + "="*80 + "\n")

# Mostrar estatísticas finais
guia.mostrar_estatisticas()
# Out:
# 🎬 **DEMONSTRAÇÃO DO SISTEMA COMPLETO**
#
# 💬 **CONSULTA 1:**
# 👤 Usuario: Quais são os principais pontos turísticos do Rio de Janeiro?
# 🎯 Roteamento: roteiro
# 🔍 Contexto: 3 documentos
# 🔍 Contexto: 3 documentos
# 🤖 **Resposta (roteiro) - 2871ms:**
# **Principais Pontos Turísticos do Rio de Janeiro**
#
# O Rio de Janeiro é uma cidade linda e vibrante, conhecida por suas praias, montanhas e arquitetura colonial. Aqui estão os principais pontos turísticos que você não pode perder:
#
# **1. Cristo Redentor**
#
# * Localização: Corcovado, no bairro de Tijuca
# * Acessibilidade: Metro Rio (linha 1) + Trem do Corcovado
# * Horário de funcionamento: 8h às 19h (de segunda a domingo)
# * Informações: Uma das Sete Maravilhas do Mundo Moderno, o Cristo Redentor é um ícone da cidade e oferece uma vista incrível da baía de Guanabara.
#
# **2. Praia de Copacabana**
#
# * Localização: Bairro de Copacabana
# * Acessibilidade: Metro Rio (linha 2)
# * Horário de funcionamento: 24h
# * Informações: Uma das praias mais famosas do mundo, a Praia de Copacabana oferece 4km de areia branca, calçadão famoso e hotéis luxuosos.
#
# **3. Praia de Ipanema**
#
# * Localização: Bairro de Ipanema
# * Acessibilidade: Metro Rio (linha 2)
# * Horário de funcionamento: 24h
# * Informações: Outra praia famosa do Rio, a Praia de Ipanema é conhecida por suas ondas fortes e vida noturna animada.
#
# **4. Pão de Açúcar**
#
# * Localização: Bairro de Urca
# * Acessibilidade: Teleférico do Pão de Açúcar
# * Horário de funcionamento: 9h às 20h (de segunda a domingo)
# * Informações: Outro ícone da cidade, o Pão de Açúcar oferece uma vista incrível da baía de Guanabara e é um ótimo local para praticar esportes de aventura.
#
# **5. Tijuca Forest**
#
# * Localização: Bairro de Tijuca
# * Acessibilidade: Metro Rio (linha 1)
# * Horário de funcionamento: 9h às 17h (de segunda a domingo)
# * Informações: Uma floresta tropical dentro da cidade, o Tijuca Forest é um ótimo local para caminhar e se conectar com a natureza.
#
# **Roteiros Otimizados**
#
# Aqui estão alguns roteiros otimizados para você explorar os principais pontos turísticos do Rio de Janeiro:
#
# **Roteiro 1: Cristo Redentor e Praia de Copacabana**
#
# * 9h: Visite o Cristo Redentor
# * 11h: Desça do Corcovado e vá para a Praia de Copacabana
# * 13h: Almoce em um dos restaurantes da praia
# * 15h: Passeio de bicicleta ou caminhada pela praia
#
# **Roteiro 2: Praia de Ipanema e Pão de Açúcar**
#
# * 9h: Visite a Praia de Ipanema
# * 11h: Vá para o Pão de Açúcar e suba no teleférico
# * 13h: Almoce em um dos restaurantes do Pão de Açúcar
# * 15h: Passeio de bicicleta ou caminhada pela praia
#
# **Roteiro 3: Tijuca Forest e Praia de Copacabana**
#
# * 9h: Visite o Tijuca Forest
# * 11h: Desça da floresta e vá para a Praia de Copacabana
# * 13h: Almoce em um dos restaurantes da praia
# * 15h: Passeio de bicicleta ou caminhada pela praia
#
# Esses roteiros são apenas sugestões e podem ser adaptados às suas preferências e necessidades. Lembre-se de sempre respeitar as regras de segurança e proteger o meio ambiente.
#
# ================================================================================
#
# 💬 **CONSULTA 2:**
# 👤 Usuario: Como ir do aeroporto Charles de Gaulle para o centro de Paris?
#
# 🤖 **Resposta (roteiro) - 2871ms:**
# **Principais Pontos Turísticos do Rio de Janeiro**
#
# O Rio de Janeiro é uma cidade linda e vibrante, conhecida por suas praias, montanhas e arquitetura colonial. Aqui estão os principais pontos turísticos que você não pode perder:
#
# **1. Cristo Redentor**
#
# * Localização: Corcovado, no bairro de Tijuca
# * Acessibilidade: Metro Rio (linha 1) + Trem do Corcovado
# * Horário de funcionamento: 8h às 19h (de segunda a domingo)
# * Informações: Uma das Sete Maravilhas do Mundo Moderno, o Cristo Redentor é um ícone da cidade e oferece uma vista incrível da baía de Guanabara.
#
# **2. Praia de Copacabana**
#
# * Localização: Bairro de Copacabana
# * Acessibilidade: Metro Rio (linha 2)
# * Horário de funcionamento: 24h
# * Informações: Uma das praias mais famosas do mundo, a Praia de Copacabana oferece 4km de areia branca, calçadão famoso e hotéis luxuosos.
#
# **3. Praia de Ipanema**
#
# * Localização: Bairro de Ipanema
# * Acessibilidade: Metro Rio (linha 2)
# * Horário de funcionamento: 24h
# * Informações: Outra praia famosa do Rio, a Praia de Ipanema é conhecida por suas ondas fortes e vida noturna animada.
#
# **4. Pão de Açúcar**
#
# * Localização: Bairro de Urca
# * Acessibilidade: Teleférico do Pão de Açúcar
# * Horário de funcionamento: 9h às 20h (de segunda a domingo)
# * Informações: Outro ícone da cidade, o Pão de Açúcar oferece uma vista incrível da baía de Guanabara e é um ótimo local para praticar esportes de aventura.
#
# **5. Tijuca Forest**
#
# * Localização: Bairro de Tijuca
# * Acessibilidade: Metro Rio (linha 1)
# * Horário de funcionamento: 9h às 17h (de segunda a domingo)
# * Informações: Uma floresta tropical dentro da cidade, o Tijuca Forest é um ótimo local para caminhar e se conectar com a natureza.
#
# **Roteiros Otimizados**
#
# Aqui estão alguns roteiros otimizados para você explorar os principais pontos turísticos do Rio de Janeiro:
#
# **Roteiro 1: Cristo Redentor e Praia de Copacabana**
#
# * 9h: Visite o Cristo Redentor
# * 11h: Desça do Corcovado e vá para a Praia de Copacabana
# * 13h: Almoce em um dos restaurantes da praia
# * 15h: Passeio de bicicleta ou caminhada pela praia
#
# **Roteiro 2: Praia de Ipanema e Pão de Açúcar**
#
# * 9h: Visite a Praia de Ipanema
# * 11h: Vá para o Pão de Açúcar e suba no teleférico
# * 13h: Almoce em um dos restaurantes do Pão de Açúcar
# * 15h: Passeio de bicicleta ou caminhada pela praia
#
# **Roteiro 3: Tijuca Forest e Praia de Copacabana**
#
# * 9h: Visite o Tijuca Forest
# * 11h: Desça da floresta e vá para a Praia de Copacabana
# * 13h: Almoce em um dos restaurantes da praia
# * 15h: Passeio de bicicleta ou caminhada pela praia
#
# Esses roteiros são apenas sugestões e podem ser adaptados às suas preferências e necessidades. Lembre-se de sempre respeitar as regras de segurança e proteger o meio ambiente.
#
# ================================================================================
#
# 💬 **CONSULTA 2:**
# 👤 Usuario: Como ir do aeroporto Charles de Gaulle para o centro de Paris?
#
# 🎯 Roteamento: logistica
# 🎯 Roteamento: logistica
# 🔍 Contexto: 3 documentos
# 🔍 Contexto: 3 documentos
# 🤖 **Resposta (logistica) - 1704ms:**
# Como especialista em logística de viagem, posso fornecer informações práticas sobre como ir do aeroporto Charles de Gaulle para o centro de Paris.
#
# **Opções de Transporte:**
#
# 1. **RER B**: É a opção mais rápida e econômica. O RER B é um trem de alta velocidade que conecta o aeroporto Charles de Gaulle ao centro de Paris em cerca de 45 minutos. O custo é de aproximadamente 10,30 euros. Para chegar ao RER B, siga as placas de sinalização no aeroporto e siga as instruções para chegar à estação RER B.
# 2. **TGV (Trem de Alta Velocidade)**: É uma opção mais rápida, mas também mais cara. O TGV é um trem de alta velocidade que conecta o aeroporto Charles de Gaulle ao centro de Paris em cerca de 30 minutos. O custo é de aproximadamente 22,50 euros.
# 3. **Taxi**: É uma opção mais cara, mas também mais conveniente. O tempo de viagem é de cerca de 45 minutos, dependendo do tráfego. O custo é de aproximadamente 60-80 euros.
# 4. **Uber**: É uma opção mais cara do que o táxi, mas também mais conveniente. O tempo de viagem é de cerca de 45 minutos, dependendo do tráfego. O custo é de aproximadamente 60-80 euros.
# 5. **Lei**: É uma opção mais econômica do que o táxi, mas também mais lenta. O tempo de viagem é de cerca de 1 hora, dependendo do tráfego. O custo é de aproximadamente 30-40 euros.
#
# **Hospedagem:**
#
# Paris é uma cidade com muitas opções de hospedagem, desde hotéis de luxo até hostels econômicos. É importante reservar com antecedência, especialmente durante a temporada alta.
#
# **Locomoção:**
#
# Paris é uma cidade fácil de se locomover, com muitas opções de transporte público, incluindo metrô, ônibus e bicicletas. É importante comprar um bilhete de transporte público para evitar problemas.
#
# **Dicas Operacionais:**
#
# * Certifique-se de ter um bilhete de transporte público válido antes de embarcar no RER B ou TGV.
# * Verifique o horário de funcionamento do RER B e TGV antes de viajar.
# * Reserve um táxi ou Uber com antecedência para evitar problemas.
# * Certifique-se de ter um mapa de Paris para se locomover facilmente.
# * Não esqueça de verificar o tempo de viagem e o custo antes de escolher uma opção de transporte.
#
# Espero que essas informações sejam úteis para você planejar sua viagem para Paris!
#
# ================================================================================
#
# 💬 **CONSULTA 3:**
# 👤 Usuario: Que pratos típicos franceses devo experimentar?
#
# 🤖 **Resposta (logistica) - 1704ms:**
# Como especialista em logística de viagem, posso fornecer informações práticas sobre como ir do aeroporto Charles de Gaulle para o centro de Paris.
#
# **Opções de Transporte:**
#
# 1. **RER B**: É a opção mais rápida e econômica. O RER B é um trem de alta velocidade que conecta o aeroporto Charles de Gaulle ao centro de Paris em cerca de 45 minutos. O custo é de aproximadamente 10,30 euros. Para chegar ao RER B, siga as placas de sinalização no aeroporto e siga as instruções para chegar à estação RER B.
# 2. **TGV (Trem de Alta Velocidade)**: É uma opção mais rápida, mas também mais cara. O TGV é um trem de alta velocidade que conecta o aeroporto Charles de Gaulle ao centro de Paris em cerca de 30 minutos. O custo é de aproximadamente 22,50 euros.
# 3. **Taxi**: É uma opção mais cara, mas também mais conveniente. O tempo de viagem é de cerca de 45 minutos, dependendo do tráfego. O custo é de aproximadamente 60-80 euros.
# 4. **Uber**: É uma opção mais cara do que o táxi, mas também mais conveniente. O tempo de viagem é de cerca de 45 minutos, dependendo do tráfego. O custo é de aproximadamente 60-80 euros.
# 5. **Lei**: É uma opção mais econômica do que o táxi, mas também mais lenta. O tempo de viagem é de cerca de 1 hora, dependendo do tráfego. O custo é de aproximadamente 30-40 euros.
#
# **Hospedagem:**
#
# Paris é uma cidade com muitas opções de hospedagem, desde hotéis de luxo até hostels econômicos. É importante reservar com antecedência, especialmente durante a temporada alta.
#
# **Locomoção:**
#
# Paris é uma cidade fácil de se locomover, com muitas opções de transporte público, incluindo metrô, ônibus e bicicletas. É importante comprar um bilhete de transporte público para evitar problemas.
#
# **Dicas Operacionais:**
#
# * Certifique-se de ter um bilhete de transporte público válido antes de embarcar no RER B ou TGV.
# * Verifique o horário de funcionamento do RER B e TGV antes de viajar.
# * Reserve um táxi ou Uber com antecedência para evitar problemas.
# * Certifique-se de ter um mapa de Paris para se locomover facilmente.
# * Não esqueça de verificar o tempo de viagem e o custo antes de escolher uma opção de transporte.
#
# Espero que essas informações sejam úteis para você planejar sua viagem para Paris!
#
# ================================================================================
#
# 💬 **CONSULTA 3:**
# 👤 Usuario: Que pratos típicos franceses devo experimentar?
#
# 🎯 Roteamento: info-local
# 🔍 Contexto: 3 documentos
# 🎯 Roteamento: info-local
# 🔍 Contexto: 3 documentos
# 🤖 **Resposta (info-local) - 2195ms:**
# Bonjour! Seja bem-vindo ao coração da França, onde a gastronomia é uma das maiores atrações! Como especialista em informações locais, estou aqui para compartilhar com você os pratos típicos franceses que você não pode perder.
#
# **Os clássicos**
#
# 1. **Coq au Vin**: um prato clássico francês feito com frango cozido em vinho tinto, cebola, alho e especiarias. É um dos pratos mais populares da França e você pode encontrá-lo em qualquer restaurante.
# 2. **Bouillabaisse**: um caldo de peixe provençal que é uma das especialidades da cidade de Marselha. É feito com uma variedade de peixes e frutos do mar, e é servido com uma fatia de pão para mergulhar.
# 3. **Duck L'Orange**: um prato clássico francês feito com pato cozido em uma salsa de laranja e especiarias. É um dos pratos mais populares da França e você pode encontrá-lo em qualquer restaurante.
#
# **Os pratos regionais**
#
# 1. **Escargots**: um prato típico da região da Borgonha, feito com caracóis cozidos em manteiga e azeite.
# 2. **Ratatouille**: um prato típico da região da Provença, feito com vegetais cozidos em azeite e especiarias.
# 3. **Tarte Tatin**: um prato típico da região da Normandia, feito com maçãs cozidas em manteiga e açúcar, e servido com um creme de leite.
#
# **Dicas e segredos**
#
# 1. **Experimente os produtos locais**: a França é conhecida por seus produtos locais de alta qualidade, como queijo, manteiga e vinho. Experimente os produtos locais para saborear a autenticidade da culinária francesa.
# 2. **Não perca a oportunidade de experimentar os pratos de rua**: os pratos de rua são uma ótima maneira de experimentar a culinária francesa em um ambiente autêntico e barato.
# 3. **Não se esqueça de experimentar o café**: o café é uma parte importante da cultura francesa, e você pode encontrar cafés em qualquer lugar da cidade.
#
# Espero que essas dicas e recomendações tenham ajudado a planejar sua viagem à França. Lembre-se de que a culinária francesa é uma das maiores atrações da França, e você não pode perder a oportunidade de experimentar os pratos típicos franceses. Bon appétit!
#
# ================================================================================
#
# 💬 **CONSULTA 4:**
# 👤 Usuario: Como dizer 'onde fica o banheiro' em francês?
#
# 🤖 **Resposta (info-local) - 2195ms:**
# Bonjour! Seja bem-vindo ao coração da França, onde a gastronomia é uma das maiores atrações! Como especialista em informações locais, estou aqui para compartilhar com você os pratos típicos franceses que você não pode perder.
#
# **Os clássicos**
#
# 1. **Coq au Vin**: um prato clássico francês feito com frango cozido em vinho tinto, cebola, alho e especiarias. É um dos pratos mais populares da França e você pode encontrá-lo em qualquer restaurante.
# 2. **Bouillabaisse**: um caldo de peixe provençal que é uma das especialidades da cidade de Marselha. É feito com uma variedade de peixes e frutos do mar, e é servido com uma fatia de pão para mergulhar.
# 3. **Duck L'Orange**: um prato clássico francês feito com pato cozido em uma salsa de laranja e especiarias. É um dos pratos mais populares da França e você pode encontrá-lo em qualquer restaurante.
#
# **Os pratos regionais**
#
# 1. **Escargots**: um prato típico da região da Borgonha, feito com caracóis cozidos em manteiga e azeite.
# 2. **Ratatouille**: um prato típico da região da Provença, feito com vegetais cozidos em azeite e especiarias.
# 3. **Tarte Tatin**: um prato típico da região da Normandia, feito com maçãs cozidas em manteiga e açúcar, e servido com um creme de leite.
#
# **Dicas e segredos**
#
# 1. **Experimente os produtos locais**: a França é conhecida por seus produtos locais de alta qualidade, como queijo, manteiga e vinho. Experimente os produtos locais para saborear a autenticidade da culinária francesa.
# 2. **Não perca a oportunidade de experimentar os pratos de rua**: os pratos de rua são uma ótima maneira de experimentar a culinária francesa em um ambiente autêntico e barato.
# 3. **Não se esqueça de experimentar o café**: o café é uma parte importante da cultura francesa, e você pode encontrar cafés em qualquer lugar da cidade.
#
# Espero que essas dicas e recomendações tenham ajudado a planejar sua viagem à França. Lembre-se de que a culinária francesa é uma das maiores atrações da França, e você não pode perder a oportunidade de experimentar os pratos típicos franceses. Bon appétit!
#
# ================================================================================
#
# 💬 **CONSULTA 4:**
# 👤 Usuario: Como dizer 'onde fica o banheiro' em francês?
#
# 🎯 Roteamento: traducao
# 🎯 Roteamento: traducao
# 🔍 Contexto: 3 documentos
# 🔍 Contexto: 3 documentos
# 🤖 **Resposta (traducao) - 1525ms:**
# Como especialista em tradução e comunicação, posso ajudar a responder à sua pergunta.
#
# A frase "onde fica o banheiro" em francês é:
#
# "Où est la salle de bain?"
#
# Pronúncia: /u e la sal de ben/
#
# Se você quiser ser mais direto e perguntar apenas sobre o banheiro público, pode usar:
#
# "Où sont les toilettes?"
#
# Pronúncia: /u soh leh twal-e/
#
# Se você estiver em um local específico, como um restaurante ou um shopping, pode perguntar:
#
# "Où sont les toilettes ici?"
#
# Pronúncia: /u soh leh twal-e ee see/
#
# Dicas de comunicação:
#
# - Se você não entender a resposta, não hesite em perguntar novamente ou pedir ajuda.
# - Se você estiver em um local com um mapa ou um cartaz com indicações, pode usar essas ferramentas para ajudar a encontrar o banheiro.
# - Se você estiver em um local com um funcionário ou um atendente, pode perguntar-lhes diretamente onde fica o banheiro.
#
# Frases úteis adicionais:
#
# - "Je voudrais aller aux toilettes, s'il vous plaît." (Eu gostaria de ir ao banheiro, por favor.)
# - "Pouvez-vous m'aider à trouver les toilettes?" (Pode me ajudar a encontrar o banheiro?)
# - "Je suis perdu(e), où sont les toilettes?" (Eu estou perdido, onde fica o banheiro?)
#
# Espero que essas informações sejam úteis! Se você tiver mais perguntas, sinta-se à vontade para perguntar.
#
# ================================================================================
#
# 📊 **ESTATÍSTICAS DO SISTEMA:**
#    📈 Total de consultas: 4
#    ⚡ Tempo médio: 2073.8ms
#
#    🎯 **Por especialidade:**
#      • roteiro: 1
#      • logistica: 1
#      • info-local: 1
#      • traducao: 1
# 🤖 **Resposta (traducao) - 1525ms:**
# Como especialista em tradução e comunicação, posso ajudar a responder à sua pergunta.
#
# A frase "onde fica o banheiro" em francês é:
#
# "Où est la salle de bain?"
#
# Pronúncia: /u e la sal de ben/
#
# Se você quiser ser mais direto e perguntar apenas sobre o banheiro público, pode usar:
#
# "Où sont les toilettes?"
#
# Pronúncia: /u soh leh twal-e/
#
# Se você estiver em um local específico, como um restaurante ou um shopping, pode perguntar:
#
# "Où sont les toilettes ici?"
#
# Pronúncia: /u soh leh twal-e ee see/
#
# Dicas de comunicação:
#
# - Se você não entender a resposta, não hesite em perguntar novamente ou pedir ajuda.
# - Se você estiver em um local com um mapa ou um cartaz com indicações, pode usar essas ferramentas para ajudar a encontrar o banheiro.
# - Se você estiver em um local com um funcionário ou um atendente, pode perguntar-lhes diretamente onde fica o banheiro.
#
# Frases úteis adicionais:
#
# - "Je voudrais aller aux toilettes, s'il vous plaît." (Eu gostaria de ir ao banheiro, por favor.)
# - "Pouvez-vous m'aider à trouver les toilettes?" (Pode me ajudar a encontrar o banheiro?)
# - "Je suis perdu(e), où sont les toilettes?" (Eu estou perdido, onde fica o banheiro?)
#
# Espero que essas informações sejam úteis! Se você tiver mais perguntas, sinta-se à vontade para perguntar.
#
# ================================================================================
#
# 📊 **ESTATÍSTICAS DO SISTEMA:**
#    📈 Total de consultas: 4
#    ⚡ Tempo médio: 2073.8ms
#
#    🎯 **Por especialidade:**
#      • roteiro: 1
#      • logistica: 1
#      • info-local: 1
#      • traducao: 1

# %% [markdown]
# ## 9️⃣ **Interface de Chat Simples**

# %%
def chat_interativo(max_interacoes: int = 3):
    """
    Interface de chat simples para interação com o usuário.
    """
    print("💬 **CHAT INTERATIVO ATIVADO!**")
    print("🎯 Pergunte sobre turismo (Rio ou Paris)")
    print("✋ Digite 'sair' para encerrar\n")
    
    # Perguntas de exemplo (para demonstração)
    perguntas_exemplo = [
        "O que visitar no Rio em 2 dias?",
        "Melhor forma de se locomover em Paris?",
        "Dicas de segurança para turistas?"
    ]
    
    for i in range(max_interacoes):
        # Simular entrada do usuário
        if i < len(perguntas_exemplo):
            pergunta = perguntas_exemplo[i]
            print(f"👤 Usuário: {pergunta}")
        else:
            break
            
        # Processar pergunta
        resultado = guia.processar_consulta(pergunta)
        
        # Mostrar resposta
        print(f"🤖 Guia ({resultado['especialidade']}): {resultado['resposta']}\n")
        
        # Simular pausa
        time.sleep(0.5)
    
    print("👋 Chat encerrado!")
    guia.mostrar_estatisticas()

# Executar chat demo
chat_interativo()
# Out:
# 💬 **CHAT INTERATIVO ATIVADO!**
# 🎯 Pergunte sobre turismo (Rio ou Paris)
# ✋ Digite 'sair' para encerrar
#
# 👤 Usuário: O que visitar no Rio em 2 dias?
# 🤖 Guia (roteiro): **Roteiro Turístico para 2 Dias no Rio de Janeiro**
#
# **Dia 1:**
#
# **Manhã**
#
# * 9h: Comece o dia tomando um café na Praça XV, um local histórico e charmoso no centro do Rio.
# * 10h: Visite o Museu Nacional de Belas Artes, localizado na Praça Floriano, que abriga uma das maiores coleções de arte brasileira.
# * 12h: Almoce no bairro de Santa Teresa, conhecido por suas ruas estreitas e casas coloridas. Experimente a culinária local em um dos muitos restaurantes da região.
#
# **Tarde**
#
# * 14h: Suba para o Corcovado, um dos pontos turísticos mais famosos do Rio, e visite a Estátua do Cristo Redentor, uma das Sete Maravilhas do Mundo.
# * 17h: Desça para o bairro de Lapa, conhecido por suas ruas animadas e bares. Visite o Arcos da Lapa, um local icônico e fotogênico.
#
# **Noite**
#
# * 20h: Desfrute de uma noite animada no bairro de Copacabana, conhecido por suas praias e hotéis luxuosos. Caminhe pelo calçadão e aproveite a atmosfera.
#
# **Dia 2:**
#
# **Manhã**
#
# * 9h: Visite a Praia de Copacabana, uma das praias mais famosas do mundo. Desfrute do sol, da areia e da água cristalina.
# * 11h: Almoce em um dos muitos restaurantes da praia e aproveite a vista.
#
# **Tarde**
#
# * 13h: Visite o Museu do Índio, localizado no bairro de Santa Teresa, que abriga uma coleção de arte e objetos indígenas.
# * 15h: Desfrute de uma caminhada pela Praia de Ipanema, conhecida por suas ondas fortes e praias animadas.
#
# **Transporte**
#
# * Utilize o Metro Rio para se locomover entre os bairros. As linhas 1, 2 e 4 conectam os principais pontos turísticos.
# * Se preferir, utilize o Uber ou o 99, que são serviços de transporte seguro e conveniente.
#
# **Dicas**
#
# * Certifique-se de reservar os ingressos para os pontos turísticos mais populares com antecedência.
# * Não esqueça de levar protetor solar, chapéu e óculos de sol para proteger-se do sol forte.
# * Experimente a culinária local em um dos muitos restaurantes da cidade.
#
# Espero que esse roteiro turístico ajude você a planejar sua viagem ao Rio de Janeiro!
#
# 🤖 Guia (roteiro): **Roteiro Turístico para 2 Dias no Rio de Janeiro**
#
# **Dia 1:**
#
# **Manhã**
#
# * 9h: Comece o dia tomando um café na Praça XV, um local histórico e charmoso no centro do Rio.
# * 10h: Visite o Museu Nacional de Belas Artes, localizado na Praça Floriano, que abriga uma das maiores coleções de arte brasileira.
# * 12h: Almoce no bairro de Santa Teresa, conhecido por suas ruas estreitas e casas coloridas. Experimente a culinária local em um dos muitos restaurantes da região.
#
# **Tarde**
#
# * 14h: Suba para o Corcovado, um dos pontos turísticos mais famosos do Rio, e visite a Estátua do Cristo Redentor, uma das Sete Maravilhas do Mundo.
# * 17h: Desça para o bairro de Lapa, conhecido por suas ruas animadas e bares. Visite o Arcos da Lapa, um local icônico e fotogênico.
#
# **Noite**
#
# * 20h: Desfrute de uma noite animada no bairro de Copacabana, conhecido por suas praias e hotéis luxuosos. Caminhe pelo calçadão e aproveite a atmosfera.
#
# **Dia 2:**
#
# **Manhã**
#
# * 9h: Visite a Praia de Copacabana, uma das praias mais famosas do mundo. Desfrute do sol, da areia e da água cristalina.
# * 11h: Almoce em um dos muitos restaurantes da praia e aproveite a vista.
#
# **Tarde**
#
# * 13h: Visite o Museu do Índio, localizado no bairro de Santa Teresa, que abriga uma coleção de arte e objetos indígenas.
# * 15h: Desfrute de uma caminhada pela Praia de Ipanema, conhecida por suas ondas fortes e praias animadas.
#
# **Transporte**
#
# * Utilize o Metro Rio para se locomover entre os bairros. As linhas 1, 2 e 4 conectam os principais pontos turísticos.
# * Se preferir, utilize o Uber ou o 99, que são serviços de transporte seguro e conveniente.
#
# **Dicas**
#
# * Certifique-se de reservar os ingressos para os pontos turísticos mais populares com antecedência.
# * Não esqueça de levar protetor solar, chapéu e óculos de sol para proteger-se do sol forte.
# * Experimente a culinária local em um dos muitos restaurantes da cidade.
#
# Espero que esse roteiro turístico ajude você a planejar sua viagem ao Rio de Janeiro!
#
# 👤 Usuário: Melhor forma de se locomover em Paris?
# 👤 Usuário: Melhor forma de se locomover em Paris?
# 🤖 Guia (logistica): Como especialista em logística de viagem, posso fornecer informações práticas sobre transporte, hospedagem e locomoção em Paris.
#
# **Transporte:**
#
# A melhor forma de se locomover em Paris é utilizando o sistema de transporte público eficiente e amplo da cidade. Aqui estão algumas opções:
#
# 1. **Metro**: O metro de Paris é uma das melhores maneiras de se locomover pela cidade. Existem 16 linhas que conectam os principais pontos turísticos, incluindo a Torre Eiffel e o Louvre.
# 2. **RER**: O RER (Reseau Express Régional) é um sistema de trens que conecta os subúrbios de Paris ao centro da cidade. É uma boa opção para se locomover para o aeroporto Charles de Gaulle.
# 3. **Buses**: Os ônibus de Paris são uma boa opção para se locomover pela cidade, especialmente para os pontos turísticos que não estão conectados ao metro.
# 4. **Bicicletas**: Paris é uma cidade muito ciclável, e as bicicletas são uma boa opção para se locomover pela cidade. Existem várias estações de aluguel de bicicletas espalhadas pela cidade.
#
# **Hospedagem:**
#
# Aqui estão algumas dicas para escolher a melhor hospedagem em Paris:
#
# 1. **Hotéis**: Existem muitos hotéis de diferentes categorias em Paris, desde hotéis econômicos até luxuosos. É importante reservar com antecedência, especialmente durante a temporada alta.
# 2. **Pousadas**: As pousadas são uma boa opção para se hospedar em Paris, especialmente para os viajantes que buscam uma experiência mais autêntica.
# 3. **Apartamentos**: Alugar um apartamento em Paris pode ser uma boa opção para se hospedar, especialmente para os viajantes que buscam mais espaço e confort.
#
# **Locomoção:**
#
# Aqui estão algumas dicas para se locomover em Paris:
#
# 1. **Cartão de transporte**: O cartão de transporte de Paris é uma boa opção para se locomover pela cidade. Pode ser comprado em qualquer estação de metro ou na loja de bilhetes da SNCF.
# 2. **Mapa da cidade**: É importante ter um mapa da cidade para se locomover pela Paris. Existem muitos mapas disponíveis em papel ou digital.
# 3. **Aplicativos de navegação**: Existem muitos aplicativos de navegação disponíveis para se locomover pela Paris, incluindo o Google Maps e o Citymapper.
#
# **Detalhes operacionais úteis:**
#
# 1. **Horário de funcionamento**: O horário de funcionamento do metro e dos ônibus varia dependendo da linha e do dia da semana. É importante verificar o horário antes de sair.
# 2. **Preços**: Os preços do transporte público em Paris variam dependendo da opção escolhida. É importante verificar os preços antes de comprar o bilhete.
# 3. **Segurança**: A segurança é um problema importante em Paris. É importante estar atento às suas pertences e evitar andar sozinho em áreas isoladas à noite.
#
# Espero que essas informações sejam úteis para você planejar sua viagem a Paris!
#
# 🤖 Guia (logistica): Como especialista em logística de viagem, posso fornecer informações práticas sobre transporte, hospedagem e locomoção em Paris.
#
# **Transporte:**
#
# A melhor forma de se locomover em Paris é utilizando o sistema de transporte público eficiente e amplo da cidade. Aqui estão algumas opções:
#
# 1. **Metro**: O metro de Paris é uma das melhores maneiras de se locomover pela cidade. Existem 16 linhas que conectam os principais pontos turísticos, incluindo a Torre Eiffel e o Louvre.
# 2. **RER**: O RER (Reseau Express Régional) é um sistema de trens que conecta os subúrbios de Paris ao centro da cidade. É uma boa opção para se locomover para o aeroporto Charles de Gaulle.
# 3. **Buses**: Os ônibus de Paris são uma boa opção para se locomover pela cidade, especialmente para os pontos turísticos que não estão conectados ao metro.
# 4. **Bicicletas**: Paris é uma cidade muito ciclável, e as bicicletas são uma boa opção para se locomover pela cidade. Existem várias estações de aluguel de bicicletas espalhadas pela cidade.
#
# **Hospedagem:**
#
# Aqui estão algumas dicas para escolher a melhor hospedagem em Paris:
#
# 1. **Hotéis**: Existem muitos hotéis de diferentes categorias em Paris, desde hotéis econômicos até luxuosos. É importante reservar com antecedência, especialmente durante a temporada alta.
# 2. **Pousadas**: As pousadas são uma boa opção para se hospedar em Paris, especialmente para os viajantes que buscam uma experiência mais autêntica.
# 3. **Apartamentos**: Alugar um apartamento em Paris pode ser uma boa opção para se hospedar, especialmente para os viajantes que buscam mais espaço e confort.
#
# **Locomoção:**
#
# Aqui estão algumas dicas para se locomover em Paris:
#
# 1. **Cartão de transporte**: O cartão de transporte de Paris é uma boa opção para se locomover pela cidade. Pode ser comprado em qualquer estação de metro ou na loja de bilhetes da SNCF.
# 2. **Mapa da cidade**: É importante ter um mapa da cidade para se locomover pela Paris. Existem muitos mapas disponíveis em papel ou digital.
# 3. **Aplicativos de navegação**: Existem muitos aplicativos de navegação disponíveis para se locomover pela Paris, incluindo o Google Maps e o Citymapper.
#
# **Detalhes operacionais úteis:**
#
# 1. **Horário de funcionamento**: O horário de funcionamento do metro e dos ônibus varia dependendo da linha e do dia da semana. É importante verificar o horário antes de sair.
# 2. **Preços**: Os preços do transporte público em Paris variam dependendo da opção escolhida. É importante verificar os preços antes de comprar o bilhete.
# 3. **Segurança**: A segurança é um problema importante em Paris. É importante estar atento às suas pertences e evitar andar sozinho em áreas isoladas à noite.
#
# Espero que essas informações sejam úteis para você planejar sua viagem a Paris!
#
# 👤 Usuário: Dicas de segurança para turistas?
# 👤 Usuário: Dicas de segurança para turistas?
# 🤖 Guia (info-local): Olá, bem-vindos ao Rio de Janeiro! Estou aqui para compartilhar com vocês dicas de segurança e insights sobre a nossa cidade linda.
#
# **Segurança**
#
# Antes de mais nada, é importante lembrar que o Rio é uma cidade grande e diversa, com áreas seguras e não tão seguras. Aqui estão algumas dicas para vocês se sentir seguros:
#
# * **Evite andar sozinho em áreas desconhecidas**, especialmente à noite. Se você precisa ir a um lugar que não conhece, peça recomendações a um local ou use um aplicativo de transporte compartilhado.
# * **Seja cuidadoso com seus pertences**, especialmente em áreas turísticas. Mantenha seus pertences em um lugar seguro e não deixe nada de valor em público.
# * **Evite usar joias ou objetos de valor** em áreas públicas.
# * **Seja respeitoso com a cultura local**. O Rio é uma cidade com uma rica cultura e história. Seja respeitoso com as tradições e costumes locais.
#
# **Cultura e Costumes**
#
# O Rio é uma cidade que vive ao ritmo da música e da dança. Aqui estão algumas dicas sobre a cultura e os costumes locais:
#
# * **Aprenda algumas frases em português**. Os cariocas apreciam quando os turistas se esforçam para falar o português.
# * **Respeite a hora do almoço**. Os cariocas são conhecidos por suas refeições longas e agradáveis. Se você estiver em um restaurante, não se surpreenda se o serviço demorar um pouco.
# * **Aprenda sobre a história e a cultura local**. O Rio tem uma rica história e cultura. Aprender sobre ela pode ajudar a entender melhor a cidade e seus habitantes.
#
# **Gastronomia**
#
# A comida no Rio é uma das melhores do mundo! Aqui estão algumas dicas sobre a gastronomia local:
#
# * **Tente a feijoada**. É um prato típico carioca que é feito com feijão preto e carne de porco.
# * **Aprenda sobre os diferentes tipos de pão**. O Rio é famoso por seus pães, como o pão de queijo e o pão francês.
# * **Tente um açaí**. É um fruto típico da região e é muito saudável.
#
# **Dicas que só um local saberia**
#
# * **A melhor forma de se locomover pelo Rio é de ônibus**. O sistema de ônibus é eficiente e barato.
# * **A melhor hora para visitar o Cristo Redentor é de manhã**. A vista é incrível e não há tanta gente.
# * **A melhor forma de se divertir no Rio é dançando**. O Rio é uma cidade que vive ao ritmo da música e da dança.
#
# Espero que essas dicas tenham ajudado a vocês a se sentir mais seguros e confortáveis em nossa cidade linda. Se vocês tiverem alguma dúvida ou precisarem de mais informações, não hesitem em perguntar!
#
# 🤖 Guia (info-local): Olá, bem-vindos ao Rio de Janeiro! Estou aqui para compartilhar com vocês dicas de segurança e insights sobre a nossa cidade linda.
#
# **Segurança**
#
# Antes de mais nada, é importante lembrar que o Rio é uma cidade grande e diversa, com áreas seguras e não tão seguras. Aqui estão algumas dicas para vocês se sentir seguros:
#
# * **Evite andar sozinho em áreas desconhecidas**, especialmente à noite. Se você precisa ir a um lugar que não conhece, peça recomendações a um local ou use um aplicativo de transporte compartilhado.
# * **Seja cuidadoso com seus pertences**, especialmente em áreas turísticas. Mantenha seus pertences em um lugar seguro e não deixe nada de valor em público.
# * **Evite usar joias ou objetos de valor** em áreas públicas.
# * **Seja respeitoso com a cultura local**. O Rio é uma cidade com uma rica cultura e história. Seja respeitoso com as tradições e costumes locais.
#
# **Cultura e Costumes**
#
# O Rio é uma cidade que vive ao ritmo da música e da dança. Aqui estão algumas dicas sobre a cultura e os costumes locais:
#
# * **Aprenda algumas frases em português**. Os cariocas apreciam quando os turistas se esforçam para falar o português.
# * **Respeite a hora do almoço**. Os cariocas são conhecidos por suas refeições longas e agradáveis. Se você estiver em um restaurante, não se surpreenda se o serviço demorar um pouco.
# * **Aprenda sobre a história e a cultura local**. O Rio tem uma rica história e cultura. Aprender sobre ela pode ajudar a entender melhor a cidade e seus habitantes.
#
# **Gastronomia**
#
# A comida no Rio é uma das melhores do mundo! Aqui estão algumas dicas sobre a gastronomia local:
#
# * **Tente a feijoada**. É um prato típico carioca que é feito com feijão preto e carne de porco.
# * **Aprenda sobre os diferentes tipos de pão**. O Rio é famoso por seus pães, como o pão de queijo e o pão francês.
# * **Tente um açaí**. É um fruto típico da região e é muito saudável.
#
# **Dicas que só um local saberia**
#
# * **A melhor forma de se locomover pelo Rio é de ônibus**. O sistema de ônibus é eficiente e barato.
# * **A melhor hora para visitar o Cristo Redentor é de manhã**. A vista é incrível e não há tanta gente.
# * **A melhor forma de se divertir no Rio é dançando**. O Rio é uma cidade que vive ao ritmo da música e da dança.
#
# Espero que essas dicas tenham ajudado a vocês a se sentir mais seguros e confortáveis em nossa cidade linda. Se vocês tiverem alguma dúvida ou precisarem de mais informações, não hesitem em perguntar!
#
# 👋 Chat encerrado!
# 📊 **ESTATÍSTICAS DO SISTEMA:**
#    📈 Total de consultas: 7
#    ⚡ Tempo médio: 2058.6ms
#
#    🎯 **Por especialidade:**
#      • roteiro: 2
#      • logistica: 2
#      • info-local: 2
#      • traducao: 1
# 👋 Chat encerrado!
# 📊 **ESTATÍSTICAS DO SISTEMA:**
#    📈 Total de consultas: 7
#    ⚡ Tempo médio: 2058.6ms
#
#    🎯 **Por especialidade:**
#      • roteiro: 2
#      • logistica: 2
#      • info-local: 2
#      • traducao: 1

# %% [markdown]
# ## 🔟 **Função Utilitária Final**

# %%
# Função de interface mais limpa para uso externo
def perguntar_guia(pergunta: str) -> str:
    return guia.consultar(pergunta)

# Teste individual
print("🧪 **TESTE INDIVIDUAL:**")
resposta = perguntar_guia("Vale a pena viajar para Paris em abril?")
print(f"💬 {resposta}")
print("\n" + "="*60 + "\n")
# Out:
# 🧪 **TESTE INDIVIDUAL:**
# 💬 Olá, querido viajante! Estou aqui para te ajudar a decidir se vale a pena viajar para Paris em abril. Como conhecedor local, posso te dar algumas dicas e insights sobre a cultura, costumes, gastronomia e muito mais.
#
# **Clima em abril:** Em abril, o clima em Paris é geralmente suave e agradável, com temperaturas médias de 12°C a 18°C. É um ótimo momento para visitar a cidade, pois o tempo é mais estável e as multidões turísticas ainda não estão tão grandes quanto no verão.
#
# **Festivais e eventos:** Em abril, Paris é cheia de eventos e festivais interessantes. Alguns dos principais incluem:
#
# * **Festival de Jazz de Paris**: Um dos maiores festivais de jazz do mundo, com concertos e shows em diferentes locais da cidade.
# * **Festa de Primavera**: Uma celebração da chegada da primavera, com desfiles, concertos e atividades para todas as idades.
# * **Semana de Arte Contemporânea**: Uma exposição de arte contemporânea que atrai artistas e curadores de todo o mundo.
#
# **Cultura e costumes:** Paris é uma cidade rica em cultura e história. Alguns dos principais pontos turísticos incluem:
#
# * **Museu do Louvre**: Um dos maiores museus do mundo, com uma coleção impressionante de arte e artefatos históricos.
# * **Catedral de Notre-Dame**: Uma das mais famosas catedrais da Europa, com uma arquitetura impressionante e uma história rica.
# * **Montmartre**: Um bairro boêmio e artístico, com ruas estreitas e casas coloridas.
#
# **Gastronomia:** A gastronomia francesa é famosa por sua qualidade e variedade. Alguns dos principais pratos incluem:
#
# * **Coq au Vin**: Um prato clássico de frango cozido em vinho tinto, com legumes e especiarias.
# * **Bouillabaisse**: Um prato de peixe e mariscos da Provença, servido com uma sopa de peixe.
# * **Croissants**: Um dos pastéis mais famosos da França, feito com manteiga e açúcar.
#
# **Dicas:** Aqui estão algumas dicas para te ajudar a aproveitar ao máximo sua viagem a Paris em abril:
#
# * **Compre um passe Navigo**: Um passe que te permite usar o metrô e outros meios de transporte público em toda a cidade.
# * **Visite os mercados**: Os mercados de Paris são uma ótima maneira de experimentar a comida local e encontrar presentes únicos.
# * **Explore os bairros**: Paris tem muitos bairros interessantes e únicos, como Montmartre, Le Marais e Belleville.
#
# Em resumo, vale a pena viajar para Paris em abril. O clima é agradável, os eventos e festivais são interessantes e a cidade está cheia de cultura e história. Além disso, a gastronomia francesa é uma das melhores do mundo, e você terá a oportunidade de experimentar muitos pratos deliciosos. Então, não perca a chance de visitar a cidade da luz!
#
# ============================================================
#
# 💬 Olá, querido viajante! Estou aqui para te ajudar a decidir se vale a pena viajar para Paris em abril. Como conhecedor local, posso te dar algumas dicas e insights sobre a cultura, costumes, gastronomia e muito mais.
#
# **Clima em abril:** Em abril, o clima em Paris é geralmente suave e agradável, com temperaturas médias de 12°C a 18°C. É um ótimo momento para visitar a cidade, pois o tempo é mais estável e as multidões turísticas ainda não estão tão grandes quanto no verão.
#
# **Festivais e eventos:** Em abril, Paris é cheia de eventos e festivais interessantes. Alguns dos principais incluem:
#
# * **Festival de Jazz de Paris**: Um dos maiores festivais de jazz do mundo, com concertos e shows em diferentes locais da cidade.
# * **Festa de Primavera**: Uma celebração da chegada da primavera, com desfiles, concertos e atividades para todas as idades.
# * **Semana de Arte Contemporânea**: Uma exposição de arte contemporânea que atrai artistas e curadores de todo o mundo.
#
# **Cultura e costumes:** Paris é uma cidade rica em cultura e história. Alguns dos principais pontos turísticos incluem:
#
# * **Museu do Louvre**: Um dos maiores museus do mundo, com uma coleção impressionante de arte e artefatos históricos.
# * **Catedral de Notre-Dame**: Uma das mais famosas catedrais da Europa, com uma arquitetura impressionante e uma história rica.
# * **Montmartre**: Um bairro boêmio e artístico, com ruas estreitas e casas coloridas.
#
# **Gastronomia:** A gastronomia francesa é famosa por sua qualidade e variedade. Alguns dos principais pratos incluem:
#
# * **Coq au Vin**: Um prato clássico de frango cozido em vinho tinto, com legumes e especiarias.
# * **Bouillabaisse**: Um prato de peixe e mariscos da Provença, servido com uma sopa de peixe.
# * **Croissants**: Um dos pastéis mais famosos da França, feito com manteiga e açúcar.
#
# **Dicas:** Aqui estão algumas dicas para te ajudar a aproveitar ao máximo sua viagem a Paris em abril:
#
# * **Compre um passe Navigo**: Um passe que te permite usar o metrô e outros meios de transporte público em toda a cidade.
# * **Visite os mercados**: Os mercados de Paris são uma ótima maneira de experimentar a comida local e encontrar presentes únicos.
# * **Explore os bairros**: Paris tem muitos bairros interessantes e únicos, como Montmartre, Le Marais e Belleville.
#
# Em resumo, vale a pena viajar para Paris em abril. O clima é agradável, os eventos e festivais são interessantes e a cidade está cheia de cultura e história. Além disso, a gastronomia francesa é uma das melhores do mundo, e você terá a oportunidade de experimentar muitos pratos deliciosos. Então, não perca a chance de visitar a cidade da luz!
#
# ============================================================

# %% [markdown]
# ## ✅ **Resumo do Notebook 05:**
#
# ### 🚀 **Sistema Completo Implementado:**
# - 📌 **Pinecone**: Base vetorial com dados turísticos
# - 🔍 **RAG**: Recuperação inteligente de contexto
# - ⛓️ **Chains**: 4 especialistas (roteiro, logística, info-local, tradução)
# - 🎯 **Router**: Classificação automática de intenções
# - 🤖 **Interface**: Sistema unificado e intuitivo
#
# ### 📊 **Métricas do Sistema:**
# - ⚡ **Velocidade**: ~500-2000ms por consulta
# - 🎯 **Precisão**: Alta especialização por domínio
# - 🔄 **Robustez**: Fallbacks automáticos
# - 📈 **Escalabilidade**: Fácil adição de novos especialistas
#
# ### 🛠️ **Classes e Funções Principais:**
# 1. **GuiaTurismoInteligente**: Sistema principal completo
# 2. **processar_consulta()**: Fluxo completo com métricas
# 3. **consultar()**: Interface simples
# 4. **perguntar_guia()**: Interface ultra-simplificada
# 5. **chat_interativo()**: Demo de conversação
#
# ### 🧪 **Demonstrações Realizadas:**
# - ✅ Sistema completo end-to-end
# - ✅ Chat interativo funcional
# - ✅ Métricas em tempo real
# - ✅ Interface limpa para uso externo
#
# ### 🎯 **Fluxo Completo:**
# ```
# Usuário → Router → RAG → Chain Especializada → Resposta
# ```
#
# ---
# 🎉 **SISTEMA TURÍSTICO INTELIGENTE COMPLETO!**
#
# **Para usar:**
# ```python
# resposta = perguntar_guia("O que visitar no Rio?")
# ```
